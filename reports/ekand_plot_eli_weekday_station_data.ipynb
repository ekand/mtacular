# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("spreadsheet_ins_outs_eli.csv")

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
df.columns
# Out:
# Index(['STATION         ', 'INS', 'OUTS'], dtype='object')

# %%
df.columns = [column.strip() for column in df.columns]

# %%
df.columns
# Out:
# Index(['STATION', 'INS', 'OUTS'], dtype='object')

# %%
df_10 = df.iloc[:10]
plt.bar(df_10.STATION, df_10.INS)
plt.xticks(rotation=45)
plt.savefig('ekand_weekday_busy_stations_eli_data.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
asdf = amd.group_by_day_of_week
